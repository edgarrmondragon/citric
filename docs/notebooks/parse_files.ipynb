# %% [markdown]
# # Experimental: parse survey, group and question files

# %%
import xml.etree.ElementTree as ET  # noqa: S405

tree = ET.parse("../../examples/free_text.lsq")  # noqa: S314

# %%
for fieldname in tree.find("questions").find("fields").findall("fieldname"):
    display(fieldname.text)
# Out:
# 'qid'
# 'parent_qid'
# 'sid'
# 'gid'
# 'type'
# 'title'
# 'preg'
# 'other'
# 'mandatory'
# 'encrypted'
# 'question_order'
# 'scale_id'
# 'same_default'
# 'relevance'
# 'modulename'

# %%
for entry in tree.find("questions").find("rows").find("row"):
    display(f"{entry.tag} = {entry.text}")
# Out:
# 'qid = 142'
# 'parent_qid = 0'
# 'sid = 123456'
# 'gid = 96'
# 'type = T'
# 'title = FREETEXTEXAMPLE'
# 'preg = None'
# 'other = N'
# 'mandatory = N'
# 'encrypted = N'
# 'question_order = 0'
# 'scale_id = 0'
# 'same_default = 0'
# 'relevance = 1'
# 'modulename = None'
